# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import time
import random
import cv2
from tqdm import tqdm
import dgl
import networkx as nx
from torch.utils.data import DataLoader
from torchvision.datasets import STL10,VOCSegmentation
from torchvision import transforms
import torchvision.transforms.functional as F
import matplotlib.pyplot as plt

# %%
STL10_train = VOCSegmentation("VOCSeg", year='2012', image_set='train', download=False)

# %%
print(type(STL10_train))
# Out:
# <class 'torchvision.datasets.voc.VOCSegmentation'>

# %%
img=STL10_train[0]

# %%
image=img[0]
seg=img[1]

# %%
print(np.array(image).shape)
plt.imshow(image)
plt.show()
# Out:
# (281, 500, 3)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=500x281 at 0x7F78F4C590D0>

# %%
seg=np.array(seg)
print(seg.shape)
# Out:
# (281, 500)

# %%
seg=torch.tensor(seg)
print(seg.shape)
# Out:
# torch.Size([281, 500])
